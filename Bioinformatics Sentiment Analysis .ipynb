# %%
import tweepy
import nltk
import pandas as pd 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#declare Twitter API Authentication variables
consumer_key = "Pt8cpPBSLjntQbBkCXgM23AM1"
consmer_secret = "WMKaY7ONlJnZUB2GpMnh1HcFykWftntAFOvSLEQ4jdKOuq5Hop"
access_token = "516297917-TRSYrcBUhr1l0BSczW2iNBZJITmXapHeiR9QFSna"
access_token_secret = "MwE0USG4k5e76ykL91TF3ooVwvubSqD79ccVwlmXOCs8t"

#create a OAuthHandler instance to handle OAtuh Authentication
auth = tweepy.OAuthHandler(consumer_key, consmer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search("Bioinformatics", count=100)

data= pd.DataFrame(data=[tweet.text for tweet in tweets], columns =['Tweets'])
display(data.head(15))

print(tweets[0].created_at)
# Out:
#                                                Tweets
# 0   RT @AlbertVilella: My take on recent advanceme...
# 1   RT @AlbertVilella: Who is going to be the bigg...
# 2   RT @pauldcotter: A short ‘long weekend’ for me...
# 3   Who is going to be the biggest contributor to ...
# 4   My take on recent advancements on #Compute #Ac...
# 5   RT @KeywanHP: We are hiring a Senior IT System...
# 6   RT @KeywanHP: We are hiring a Senior IT System...
# 7   RT @ecSeq: Conversations with Bioinnovators - ...
# 8   RT @jmeesvliz: You want to be part of this new...
# 9   From psychology to bioinformatics, VLIZ is hir...
# 10  RT @jmeesvliz: You want to be part of this new...
# 11  RT @EpiDiverse: Our last bioinformatician is @...
# 12  RT @SLUglobal1: How can Artificial Intelligenc...
# 13  #bioinformatics #bioit ChEA3 https://t.co/AyLP...
# 14  RT @lgatt0: Five stages of bioinformatics soft...
# 2019-05-06 10:42:13
